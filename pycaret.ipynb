# %%
import pandas as pd
from pycaret.regression import *

# %%
train = pd.read_csv('./data/train.csv',index_col=0)
test = pd.read_csv('./data/test.csv',index_col=0)

# %%
exp1 = setup(train, target = 'loss', silent=True)
# Out:
# <style  type="text/css" >
# #T_5f7fc_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_5f7fc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f7fc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5f7fc_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5f7fc_row0_col1" class="data row0 col1" >2953</td>
#             </tr>
#             <tr>
#                         <th id="T_5f7fc_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5f7fc_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_5f7fc_row1_col1" class="data row1 col1" >loss</td>
#             </tr>
#             <tr>
# ...

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_14a73_row10_col0,#T_14a73_row10_col1,#T_14a73_row10_col2,#T_14a73_row10_col3,#T_14a73_row10_col4,#T_14a73_row10_col5{
#             background:  yellow;
#         }</style><table id="T_14a73_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14a73_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_14a73_row0_col0" class="data row0 col0" >6.1457</td>
#                         <td id="T_14a73_row0_col1" class="data row0 col1" >62.1477</td>
# ...

# %%
catboost = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_5346e_row10_col0,#T_5346e_row10_col1,#T_5346e_row10_col2,#T_5346e_row10_col3,#T_5346e_row10_col4,#T_5346e_row10_col5{
#             background:  yellow;
#         }</style><table id="T_5346e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5346e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5346e_row0_col0" class="data row0 col0" >6.1288</td>
#                         <td id="T_5346e_row0_col1" class="data row0 col1" >62.0391</td>
# ...

# %%
xgboost = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_a4364_row10_col0,#T_a4364_row10_col1,#T_a4364_row10_col2,#T_a4364_row10_col3,#T_a4364_row10_col4,#T_a4364_row10_col5{
#             background:  yellow;
#         }</style><table id="T_a4364_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4364_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a4364_row0_col0" class="data row0 col0" >6.1858</td>
#                         <td id="T_a4364_row0_col1" class="data row0 col1" >63.4101</td>
# ...

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style  type="text/css" >
# #T_87c26_row10_col0,#T_87c26_row10_col1,#T_87c26_row10_col2,#T_87c26_row10_col3,#T_87c26_row10_col4,#T_87c26_row10_col5{
#             background:  yellow;
#         }</style><table id="T_87c26_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87c26_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_87c26_row0_col0" class="data row0 col0" >6.1804</td>
#                         <td id="T_87c26_row0_col1" class="data row0 col1" >62.7088</td>
# ...

# %%
tuned_catboost = tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_aa2fa_row10_col0,#T_aa2fa_row10_col1,#T_aa2fa_row10_col2,#T_aa2fa_row10_col3,#T_aa2fa_row10_col4,#T_aa2fa_row10_col5{
#             background:  yellow;
#         }</style><table id="T_aa2fa_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa2fa_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aa2fa_row0_col0" class="data row0 col0" >6.1301</td>
#                         <td id="T_aa2fa_row0_col1" class="data row0 col1" >61.8919</td>
# ...

# %%
tuned_xgboost = tune_model(xgboost)
# Out:
# <style  type="text/css" >
# #T_e6b5a_row10_col0,#T_e6b5a_row10_col1,#T_e6b5a_row10_col2,#T_e6b5a_row10_col3,#T_e6b5a_row10_col4,#T_e6b5a_row10_col5{
#             background:  yellow;
#         }</style><table id="T_e6b5a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6b5a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e6b5a_row0_col0" class="data row0 col0" >5.8673</td>
#                         <td id="T_e6b5a_row0_col1" class="data row0 col1" >64.5416</td>
# ...

# %%
blender_specific = blend_models(estimator_list = [lightgbm,catboost,xgboost])
# Out:
# <style  type="text/css" >
# #T_cafe6_row10_col0,#T_cafe6_row10_col1,#T_cafe6_row10_col2,#T_cafe6_row10_col3,#T_cafe6_row10_col4,#T_cafe6_row10_col5{
#             background:  yellow;
#         }</style><table id="T_cafe6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cafe6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cafe6_row0_col0" class="data row0 col0" >6.1357</td>
#                         <td id="T_cafe6_row0_col1" class="data row0 col1" >62.0029</td>
# ...

# %%
predictions = predict_model(blender_specific, data = test)

# %%
predictions
# Out:
#               f0   f1        f2        f3          f4        f5         f6  \
# id
# 250000  0.812665   15 -1.239120 -0.893251    295.5770  15.87120   23.04360
# 250001  0.190344  131 -0.501361  0.801921     64.8866   3.09703  344.80500
# 250002  0.919671   19 -0.057382  0.901419  11961.2000  16.39650  273.24000
# 250003  0.860985   19 -0.549509  0.471799   7501.6000   2.80698   71.08170
# 250004  0.313229   89  0.588509  0.167705   2931.2600   4.34986    1.57187
# ...          ...  ...       ...       ...         ...       ...        ...
# 399995  0.751053   77  0.666725 -1.106280  21433.3000  16.58120  122.77900
# 399996  0.734669   41  0.611225  0.740177    294.1850  10.72900   25.03340
# 399997  0.417307  142 -0.357854 -0.836640   1215.2500  10.62460  221.60400
# 399998  1.023900   17  0.367100 -0.936674   1832.3900   8.51691  262.79700
# 399999  0.249362   49  0.344670 -0.566363   2290.9300  20.80300  350.64400
#
# ...

# %%
preds_final = pd.DataFrame()
preds_final = predictions[['id', 'Label']]
preds_final = preds_final.rename(columns={"Label": "loss"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-94f2bae97943> in <module>
#       1 preds_final = pd.DataFrame()
# ----> 2 preds_final = predictions[['id', 'Label']]
#       3 preds_final = preds_final.rename(columns={"Label": "loss"})
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...

# %%
preds_final.to_csv('pycaret.csv', index=False)

# %%
preds_final
# Out:
#             loss      id
# id
# 250000  7.636024  250000
# 250001  4.465177  250001
# 250002  8.027557  250002
# 250003  8.233895  250003
# 250004  6.689487  250004
# ...          ...     ...
# 399995  7.259990  399995
# 399996  6.935918  399996
# 399997  6.473205  399997
# 399998  4.891879  399998
# 399999  6.736083  399999
#
# [150000 rows x 2 columns]
